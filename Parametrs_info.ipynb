# %%
import pandas as pd
fake_las_kgl = pd.read_csv('AllGisParams\\fake_gis_las_all_out.csv', delimiter=';')

# %%
print(fake_las_kgl.shape)
fake_las_kgl = fake_las_kgl.dropna()
print(fake_las_kgl.shape)
fake_las_kgl
# Out:
# (359635, 31)
# (279331, 31)
#         WELL_NAME  WELL_NAME_UWI    DEPT   KINT     R05      R20      R14  \
# 175           300            198  3089.7  0.102  7.4800   9.4935   8.9605
# 176           300            198  3089.8  0.102  7.5320   9.4240   8.9670
# 177           300            198  3089.9  0.102  7.2010   9.3230   8.8485
# 178           300            198  3090.0  0.102  6.8700   9.2220   8.7300
# 179           300            198  3090.1  0.102  6.6880   9.0390   8.5495
# 180           300            198  3090.2  0.102  6.5060   8.8560   8.3690
# 181           300            198  3090.3  0.102  6.3220   8.7550   8.2695
# 182           300            198  3090.4  0.102  6.1380   8.6540   8.1700
# 183           300            198  3090.5  0.102  6.1615   8.5970   8.1200
# 184           300            198  3090.6  0.102  6.1850   8.5400   8.0700
# 185           300            198  3090.7  0.102  6.3835   8.6475   8.1695
# ...

# %%
all_p = ['KINT', 'R05', 'R20', 'R14', 'R10', 'F07', 'F10', 'F14', 'R07', 'F20', 'F05', 'PHIT', 'MRES', 'SG', 'KGL', 'SXWB', 'GZ3', 'NPHI', 'GZ2', 'GZ4', 'GZ1', 'CILD', 'PROX', 'LLD', 'GZ7', 'APS', 'KPS', 'GZ5']
gz_p = ['GZ3', 'GZ2', 'GZ4', 'GZ1', 'GZ7', 'GZ5']
r_p = ['R05', 'R20', 'R14', 'R10', 'R07']
f_p = ['F07', 'F10', 'F14', 'F20', 'F05']
other_n = ['MRES', 'PROX', 'APS', 'KPS']
other = ['KINT', 'PHIT', 'SG', 'KGL', 'SXWB', 'NPHI', 'CILD',  'LLD']

# %%
fake_las_kgl[other].describe()
# Out:
#                 KINT           PHIT             SG            KGL  \
# count  279331.000000  279331.000000  279331.000000  279331.000000
# mean       -7.951629       9.351962       1.473388      28.130021
# std       209.720038      21.462795     155.768026      29.158058
# min     -4999.451500   -4996.269500   -4999.501000   -4987.407000
# 25%         0.100000       6.635000       0.000000      22.672650
# 50%         0.100000      10.548000       0.000000      24.370000
# 75%         0.100000      11.315000       0.000000      41.301000
# max       386.143000      26.117600      91.292000     122.465000
#
#                 SXWB           NPHI           CILD            LLD
# count  279331.000000  279331.000000  279331.000000  279331.000000
# mean       91.883326       8.711598     120.100018      23.248931
# std        83.326808      66.171490      66.029179     116.984835
# min     -4974.547000   -4999.218000   -9994.000000     -28.930000
# ...

# %%
# ff = ff[ff['SG']>-20]
ff[r_p].describe()
# Out:
#                  R05            R20            R14            R10  \
# count  275189.000000  275189.000000  275189.000000  275189.000000
# mean        7.283507      11.234320      10.299849       9.130517
# std         5.678156      16.144271      13.343903      10.258774
# min       -39.021000       0.000000       0.000000      -1.155000
# 25%         4.625000       5.781000       5.548000       5.292500
# 50%         5.774000       7.312000       6.960000       6.533000
# 75%         7.574500       9.014000       8.612500       8.068000
# max       500.000000     500.000000     461.945000     459.046000
#
#                  R07
# count  275189.000000
# mean        7.855752
# std         7.012517
# min       -24.319000
# 25%         5.016500
# 50%         6.120500
# 75%         7.576000
# max       500.000000

# %%
ff.shape
# Out:
# (275189, 31)
